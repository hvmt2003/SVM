# %% [markdown]
# <a href="https://colab.research.google.com/github/hvmt2003/SVM/blob/main/SVM_Regression_Non_linear_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv('/content/polynomial_logistic_50points.csv')

# %%
dataset.head(3)
# Out:
#       data1     data2  output
# 0 -0.158570  0.984806       0
# 1  1.109004 -0.621602       1
# 2  0.396415  0.207409       1

# %%
sns.scatterplot(x="data1",y="data2",data=dataset)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]

# %%
from re import X
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.svm import SVR

# %%
model=SVR(kernel='linear')
model.fit(x_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
model.score(x_test,y_test)
# Out:
# 0.4357584678157862

# %%
model.score(x_train,y_train)
# Out:
# 0.5694700045982195

# %%
sns.scatterplot(x="data1",y="data2",data=dataset)
plt.plot(dataset['data1'],model.predict(x),color='red')
plt.show()
